# %% [markdown]
# # **Large-Scale Kinship Recognition Data Challenge: Kinship Verification STARTER NOTEBOOK**
#
# We provide framework code to get you started on the competition. The notebook is broken up into three main sections.
# 1. Data Loading & Visualizing
# 2. Data Generator & Model Building
# 3. Training & Testing Model
#
# We have done the majority of the heavy lifting by making the data easily and readily accessible through Google Drive. Furthermore, we have made the task easier by creating a dataloader and fully trained end-to-end model that predicts a binary label (0 or 1) denoting whether two faces share a kinship relation.

# %% [markdown]
# **WARNING: IF YOU HAVE NOT DONE SO**
#
# Change to GPU:
#
# Runtime --> Change Runtime Type --> GPU

# %% [markdown]
# Mount to Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Install Libraries

# %%
# %%capture
# !pip install keras_vggface
# !pip install keras_applications
# !pip install deepface

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample

import cv2
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, LayerNormalization, BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2

from deepface.commons.functions import find_input_shape, normalize_input
from deepface.DeepFace import build_model

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# 2021-08-09 16:26:57.777995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# train_relationships.csv contains pairs of image paths which are positive samples (related to each other).
#
# train-faces contains the images for training itself.

# %%
# Hyperparameters
BASE_MODEL = 'VGG-Face'
IGNORE_TOP_NLAYERS_ARCH = 2 #-11 #6
IGNORE_BOTTOM_NLAYERS_TUNE = -2 #15
IGNORE_TOP_NLAYERS_TUNE = 0
NORMALIZATION = 'base'
BASE_PATH = "/root/KinshipRecognition"

# Modify paths as per your method of saving them
train_file_path = f"{BASE_PATH}/data/aug_train_ds.csv"
train_folders_path = f"{BASE_PATH}/data/train/train-faces/"
# All images belonging to families F09** will be used to create the validation set while training the model
# For final submission, you can add these to the training data as well
val_families = "F06"

# Get input shape and normalization method.
input_shape = find_input_shape(build_model(BASE_MODEL))
if NORMALIZATION not in ['raw', 'Facenet', 'Facenet2018', 'VGGFace', 'VGGFace2', 'ArcFace']:
    NORMALIZATION = 'base'
# Out:
# 2021-08-09 12:39:09.756003: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-08-09 12:39:09.756783: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-08-09 12:39:09.818099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:d8:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-08-09 12:39:09.818158: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-09 12:39:09.821794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-08-09 12:39:09.821891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-08-09 12:39:09.824925: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-08-09 12:39:09.825314: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-08-09 12:39:09.827904: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-08-09 12:39:09.829451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-08-09 12:39:09.834973: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-08-09 12:39:09.838900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-08-09 12:39:09.839655: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-09 12:39:09.850562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:d8:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-08-09 12:39:09.850626: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-09 12:39:09.850665: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-08-09 12:39:09.850695: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-08-09 12:39:09.850722: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-08-09 12:39:09.850749: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-08-09 12:39:09.850777: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-08-09 12:39:09.850816: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-08-09 12:39:09.850844: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-08-09 12:39:09.858544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-08-09 12:39:09.858599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-08-09 12:39:10.386579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-09 12:39:10.386608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-08-09 12:39:10.386614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-08-09 12:39:10.390486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 29704 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:d8:00.0, compute capability: 7.0)
# 2021-08-09 12:39:10.390923: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
all_images = glob(train_folders_path + "*/*/*.jpg")

train_images = [x for x in all_images if val_families not in x]
val_images = [x for x in all_images if val_families in x]

train_person_to_images_map = defaultdict(list)

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# %%
all_images
# Out:
# ['/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01299_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01298_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01306_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01313_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01301_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01309_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01307_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID2/P01297_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID4/P01303_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID4/P01304_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01304_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01308_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01301_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01313_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01297_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01298_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01311_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01299_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01309_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01300_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01302_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID1/P01303_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID5/P01307_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID5/P01306_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID6/P01306_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID3/P01301_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID3/P01300_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0126/MID3/P01302_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05583_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05587_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05580_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05582_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05574_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05588_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05581_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05575_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05578_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID2/P05586_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05578_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05581_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05574_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05575_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05580_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05583_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID4/P05582_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05580_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05583_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05587_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05581_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05582_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05586_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05574_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05588_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05575_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID1/P05578_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID3/P05581_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID3/P05583_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID3/P05578_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID3/P05575_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0531/MID3/P05574_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID2/P05610_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID2/P05616_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID2/P05615_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID2/P05609_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID2/P05611_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID1/P05615_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID1/P05610_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID1/P05609_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID1/P05616_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID1/P05611_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0534/MID3/P05616_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID2/P09757_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID2/P09759_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID2/P09761_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID2/P09762_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID4/P09758_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09762_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09758_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09757_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09760_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09761_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID1/P09759_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID5/P09758_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID5/P09760_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID7/P09760_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID8/P09760_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID6/P09760_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID6/P09758_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID3/P09762_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID3/P09759_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0925/MID3/P09757_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID9/P08286_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID9/P08287_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID10/P08287_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08292_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08285_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08282_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08283_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08290_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID2/P08291_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID4/P08287_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID4/P08290_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID4/P08286_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID4/P08283_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID4/P08285_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08282_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08291_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08290_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08285_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08292_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID1/P08283_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID5/P08284_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID7/P08287_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID7/P08286_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID8/P08286_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID8/P08287_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID6/P08288_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID6/P08284_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID3/P08288_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0785/MID3/P08283_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09016_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09010_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09017_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09019_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09011_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID2/P09018_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09016_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09011_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09013_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09014_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09010_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09019_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09012_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09017_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09015_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID1/P09018_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09019_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09015_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09014_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09012_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09010_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09011_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09018_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0853/MID3/P09013_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID9/P05073_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID2/P05069_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID2/P05066_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID2/P05067_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID4/P05074_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID4/P05071_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID4/P05066_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID4/P05067_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05074_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05070_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05066_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05073_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05075_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05068_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05069_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID1/P05071_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID5/P05066_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID5/P05074_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID5/P05067_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID5/P05075_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID7/P05068_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID8/P05073_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID8/P05072_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID6/P05066_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID6/P05069_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID6/P05072_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID3/P05067_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0481/MID3/P05070_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05918_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05911_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05915_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05917_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05912_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05913_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05921_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05925_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05924_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05914_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID2/P05916_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID4/P05915_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID4/P05913_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID4/P05914_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05917_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05924_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05921_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05918_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05923_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05914_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05911_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05926_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05913_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05919_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05925_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05920_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05922_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05912_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05916_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID1/P05915_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05919_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05922_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05913_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05925_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05915_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05926_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05912_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05923_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05921_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05920_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0563/MID3/P05917_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID2/P07664_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID2/P07662_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID2/P07658_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07666_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07665_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07664_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07662_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07663_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID1/P07658_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID5/P07663_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID5/P07662_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID5/P07664_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID7/P07666_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID7/P07665_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID6/P07665_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0731/MID6/P07666_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID2/P11163_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID2/P00761_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID2/P00760_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID4/P11162_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID4/P11165_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID1/P00760_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID1/P00761_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID1/P11159_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID1/P11160_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID1/P11162_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID5/P11165_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID6/P11166_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID6/P11167_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID3/P11165_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID3/P11161_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID3/P11159_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0074/MID3/P11160_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID2/P00658_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID2/P00656_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID2/P00657_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID2/P00663_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID2/P00659_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID4/P00661_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID4/P00660_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID4/P00662_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00657_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00659_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00663_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00662_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00660_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00664_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00665_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00656_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00658_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID1/P00661_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID3/P00665_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID3/P00661_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID3/P00662_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID3/P00660_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0065/MID3/P00664_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05139_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05133_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05134_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05136_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05138_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05137_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID2/P05132_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05136_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05138_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05137_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05139_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05132_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID4/P05133_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID1/P05134_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID1/P05139_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID1/P05138_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID1/P05132_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID1/P05133_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05136_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05134_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05132_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05133_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05138_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0488/MID3/P05139_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID13/P10430_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID13/P10430_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10429_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10433_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10437_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10433_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10429_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10435_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10435_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID9/P10437_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06403_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06404_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10431_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10434_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10434_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06409_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06409_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10431_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06401_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10428_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P10428_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID10/P06403_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID2/P10430_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID2/P10436_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10431_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10437_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10432_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10436_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10429_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10433_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10433_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10435_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10431_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10428_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10429_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID4/P10432_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10432_face9.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P06410_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10431_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10436_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P06405_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10430_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10428_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P06405_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10430_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10428_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10431_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID1/P10432_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10431_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10432_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10433_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10437_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10429_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10436_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10437_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10435_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10428_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10429_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10433_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10431_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID5/P10432_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10431_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10430_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10428_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10430_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10428_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID12/P10431_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10429_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10433_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10437_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10437_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10435_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10433_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10429_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID7/P10435_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10429_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10433_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10433_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10437_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10435_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10435_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10429_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID8/P10437_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID14/P10430_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10429_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10432_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10437_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10436_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10435_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10433_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10437_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10432_face8.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10429_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID6/P10433_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10428_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06403_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10431_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10436_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10431_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06401_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10436_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06403_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06404_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06409_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06409_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10428_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P06401_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID3/P10434_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID11/P10432_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0990/MID11/P10432_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01276_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01277_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01279_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01280_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01282_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01278_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01275_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01284_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01281_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01283_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID2/P01280_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01277_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01276_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01282_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01278_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01275_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID4/P01281_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01278_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01279_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01277_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01276_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01275_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01284_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01280_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01283_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID1/P01282_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01281_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01278_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01277_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01275_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01276_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID5/P01282_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID7/P01276_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID6/P01275_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID6/P01277_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID6/P01278_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID6/P01276_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01277_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01276_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01282_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01280_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01278_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0123/MID3/P01275_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID2/P02659_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID2/P02651_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID2/P02657_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID2/P02658_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID2/P02652_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID4/P02658_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID4/P02655_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02654_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02651_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02653_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02657_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02660_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02652_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02656_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID1/P02659_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID5/P02656_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02654_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02655_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02653_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02658_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02656_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02657_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0250/MID3/P02660_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05440_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05439_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05438_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05441_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05435_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID2/P05437_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID4/P05435_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID4/P05437_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID1/P05439_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID1/P05437_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID1/P05441_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID1/P05438_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID1/P05435_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID3/P05437_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID3/P05440_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0516/MID3/P05435_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10351_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10344_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10348_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10352_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10349_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10345_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10346_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID2/P10347_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10351_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10350_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10352_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10346_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10348_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10345_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10349_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10344_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10347_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID1/P10343_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID3/P10343_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID3/P10349_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID3/P10350_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0982/MID3/P10352_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04209_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04206_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04213_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04207_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04204_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04205_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04212_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID2/P04208_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04207_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04204_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04208_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04210_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04205_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04211_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04206_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04213_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID1/P04212_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04209_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04211_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04213_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04208_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04210_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0399/MID3/P04212_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID2/P03022_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID2/P03018_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID2/P03019_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID2/P03021_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID2/P03024_face9.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID4/P03019_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID4/P03018_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID4/P03026_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID4/P03028_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID4/P03024_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03026_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03022_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03019_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03021_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03028_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03025_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03024_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID1/P03018_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID5/P03018_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID5/P03026_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID5/P03025_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID5/P03019_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID3/P03019_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID3/P03018_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0283/MID3/P03024_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04937_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04939_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04934_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04935_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04936_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04938_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID2/P04933_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID4/P04937_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04934_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04939_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04940_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04936_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04938_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04937_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID1/P04933_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04939_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04940_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04934_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04933_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04935_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04938_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0468/MID3/P04937_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID2/P01731_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID4/P01737_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID4/P01733_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID4/P01736_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID4/P01740_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID4/P01732_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01731_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01734_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01735_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01732_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01733_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01739_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID1/P01738_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01736_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01732_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01737_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01738_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01739_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01734_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID5/P01733_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID6/P01735_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0162/MID3/P01732_face1.jpg',
# ...
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID5/P09279_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID5/P09275_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID6/P09284_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID6/P09283_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID3/P09282_face10.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID3/P09278_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID3/P09275_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID3/P09276_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0879/MID3/P09279_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID9/P04446_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID10/P04450_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID10/P04448_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID10/P04449_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04440_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04437_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04439_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09343_face9.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04435_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04434_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04459_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04441_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09336_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04442_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09341_face7.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09344_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09342_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04451_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09338_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04438_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09338_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04454_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P09339_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID4/P04442_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04442_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04454_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04439_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P09336_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04452_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04458_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04451_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04435_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04437_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04455_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04436_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P09338_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P09343_face16.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04457_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04438_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04441_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04456_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04434_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID1/P04461_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04434_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04458_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04440_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P09343_face22.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P09338_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04439_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P09336_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P09342_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04452_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04435_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P09344_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04437_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04460_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04461_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID5/P04457_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID12/P04450_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID8/P04446_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID8/P04447_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P09339_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P09344_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P09336_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04453_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04435_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04438_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P09342_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04459_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04451_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04454_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04440_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04437_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04439_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04434_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04441_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P04442_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID6/P09341_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04461_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04454_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04458_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04451_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04445_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04434_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04437_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P09336_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04439_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P09342_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04457_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04447_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P09343_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P09338_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04453_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P09340_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04444_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID3/P04435_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID11/P04448_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID11/P04449_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0422/MID11/P04450_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID2/P08680_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID2/P08675_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID2/P08676_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID2/P08672_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID1/P08680_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID1/P08672_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID1/P08676_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID1/P08675_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID6/P08676_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID6/P08675_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID6/P08672_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0820/MID6/P08680_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID2/P08563_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID2/P08558_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID2/P08557_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08560_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08559_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08563_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08562_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08564_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08557_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID1/P08558_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID5/P08562_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID5/P08563_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID5/P08560_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID6/P08562_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID3/P08563_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID3/P08557_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0809/MID3/P08559_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09895_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09904_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09899_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09896_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09901_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09897_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID2/P09898_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID4/P09904_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID4/P09898_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID4/P09900_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID4/P09902_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09903_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09900_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09895_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09896_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09902_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09901_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09897_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID1/P09899_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09898_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09904_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09897_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09900_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09902_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09901_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0939/MID3/P09903_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID2/P04992_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID2/P04990_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID1/P04990_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID1/P04989_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID1/P04991_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID1/P04994_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID5/P04994_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID3/P04989_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0474/MID3/P04991_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04539_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04536_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04534_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04538_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04533_face6.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04535_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID2/P04532_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID4/P04537_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID4/P04540_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID4/P04538_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04533_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04532_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04538_face2.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04539_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04534_face5.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04535_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID1/P04536_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0431/MID3/P04533_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID1/P02521_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID1/P02520_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID1/P02519_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID1/P02526_face1.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID7/P02525_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID7/P02526_face4.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID8/P02526_face3.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID6/P02526_face0.jpg',
#  '/root/KinshipRecognition/data/train/train-faces/F0238/MID3/P02526_face2.jpg',
#  ...]

# %%
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values, relationships.relationship.values))
relationships = [(x[0],x[1],x[2]) for x in relationships if x[0][:10] in ppl and x[1][:10] in ppl]

train = [x for x in relationships if val_families not in x[0]]
val = [x for x in relationships if val_families in x[0]]

# %%
def read_img(path, input_shape, normalization='base'):
    img = cv2.imread(path, -1)
    img = cv2.resize(img, input_shape)
    img = cv2.normalize(img,  np.zeros(img.shape[:2]), 0, 255, cv2.NORM_MINMAX)
    img = normalize_input(img, normalization=normalization)
    return np.array(img).astype(np.float)

# %% [markdown]
# Define a data generator. Here our data generator will generate a batch of examples which will be used by our model in training. It will generate two images, one for each in the pair as well as a label associated with it.

# %%
def gen(list_tuples, person_to_images_map, input_shape, batch_size=16, normalization='base'):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size)
        
        # All the samples are taken from train_ds.csv, labels are in the labels column
        labels = []
        for tup in batch_tuples:
            labels.append(tup[2])
        labels = np.array(labels)

        # Original images preprocessed
        X1 = [x[0] for x in batch_tuples]
        X1 = np.array([read_img(train_folders_path + x, input_shape, normalization=NORMALIZATION) for x in X1])
        X2 = [x[1] for x in batch_tuples]
        X2 = np.array([read_img(train_folders_path + x, input_shape, normalization=NORMALIZATION) for x in X2])
        
        # Mirrored images
        X1_mirror = np.asarray([cv2.flip(x, 1) for x in X1])
        X2_mirror = np.asarray([cv2.flip(x, 1) for x in X2])
        X1 = np.r_[X1, X1_mirror]
        X2 = np.r_[X2, X2_mirror]
        
        yield [X1, X2], np.r_[labels, labels]

# %% [markdown]
# Here is an ensemble model built with two resnet-50 architectures, pre-trained, with which we can apply transfer leraning on. This model achieves the baseline and the goal is to expand on this work. There have been papers exploring different architectures as well as introducing BatchNormalization among many other techniques to improve how well the model recognizes kinship between two faces.

# %%
def baseline_model(model_name, fine_tune=True):
    input_1_og = Input(shape=input_shape + (3,))
    input_2_og = Input(shape=input_shape + (3,))
#     input_1_mir = Input(shape=input_shape + (3,))
#     input_2_mir = Input(shape=input_shape + (3,))

    backbone = Sequential()
    # ORIGINAL BLOCK
    for layer in build_model(model_name).layers[:-IGNORE_TOP_NLAYERS_ARCH]:
        backbone.add(layer)
    for x in backbone.layers:
        x.trainable = False

    if fine_tune:
        for x in backbone.layers[:IGNORE_BOTTOM_NLAYERS_TUNE]:
            x.trainable = False
        if IGNORE_TOP_NLAYERS_TUNE == 0:
            for x in backbone.layers[IGNORE_BOTTOM_NLAYERS_TUNE:]:
                x.trainable = True
        else:
            for x in backbone.layers[IGNORE_BOTTOM_NLAYERS_TUNE:-IGNORE_TOP_NLAYERS_TUNE]:
                x.trainable = True

            
#     for layer in build_model(model_name).layers[:15]:
#         backbone.add(layer)
#     if fine_tune:
#         for x in backbone.layers:
#             x.trainable = True
#     else:
#         for x in backbone.layers:
#             x.trainable = False

    x1 = backbone(input_1_og)
    x2 = backbone(input_2_og)
#     x1_mir = backbone(input_1_mir)
#     x2_mir = backbone(input_2_mir)

    x1 = GlobalAvgPool2D()(x1)
    x2 = GlobalAvgPool2D()(x2)
#     x1_mir = GlobalAvgPool2D()(x1_mir)
#     x2_mir = GlobalAvgPool2D()(x2_mir)

#     x1 = tf.math.reduce_mean(tf.stack([x1_og, x1_mir], axis=0), axis=0)
#     x2 = tf.math.reduce_mean(tf.stack([x2_og, x2_mir], axis=0), axis=0)
    
    x1 = LayerNormalization(axis=-1, epsilon=0.001, center=False, scale=False)(x1)
    x2 = LayerNormalization(axis=-1, epsilon=0.001, center=False, scale=False)(x2)

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])
    x1_ = Multiply()([x1, x1])
    x2_ = Multiply()([x2, x2])
    x4 = Subtract()([x1_, x2_])
    x5 = Multiply()([x1, x2])
    x = Concatenate(axis=-1)([x3, x4, x5])
        
#     x = LayerNormalization(axis=-1, epsilon=0.001, center=True, scale=True)(x)
    x = Dense(16, activation="relu")(x)
    x = Dropout(0.05)(x)    
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.05)(x)    
    x = Dense(16, activation="tanh")(x)
#     x = LayerNormalization(axis=-1, epsilon=0.001, center=True, scale=False)(x)
    x = Dropout(0.05)(x)    
    out = Dense(1, kernel_regularizer=L2(.01), activation="sigmoid")(x)

    model = Model([input_1_og, input_2_og], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00002))

    model.summary()

    return model

# %% [markdown]
# Save the best model to your drive after each training epoch so that you can come back to it. ReduceLROnPlateau reduces the learning rate when a metric has stopped improving, in this case the validation accuracy.

# %%
model_out_path = f"{BASE_PATH}/log/vgg_face_sigmoidtest_finetune.h5"

checkpoint = ModelCheckpoint(model_out_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

callbacks_list = [checkpoint, reduce_on_plateau]

model = baseline_model(BASE_MODEL, fine_tune=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1, 1, 4096)   134260544   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 4096)         0           sequential_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 4096)         0           sequential_1[1][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 4096)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 4096)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 4096)         0           layer_normalization[0][0]
#                                                                  layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096)         0           layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096)         0           layer_normalization_1[0][0]
#                                                                  layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 4096)         0           subtract[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 4096)         0           multiply_1[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4096)         0           layer_normalization[0][0]
#                                                                  layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12288)        0           multiply[0][0]
#                                                                  subtract_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           196624      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           1088        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           1040        dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            17          dropout_4[0][0]
# ==================================================================================================
# Total params: 134,459,313
# Trainable params: 16,980,081
# Non-trainable params: 117,479,232
# __________________________________________________________________________________________________

# %%
for l in model.layers[2].layers:
    print(l.name, l.trainable)
# Out:
# zero_padding2d False
# conv2d False
# zero_padding2d_1 False
# conv2d_1 False
# max_pooling2d False
# zero_padding2d_2 False
# conv2d_2 False
# zero_padding2d_3 False
# conv2d_3 False
# max_pooling2d_1 False
# zero_padding2d_4 False
# conv2d_4 False
# zero_padding2d_5 False
# conv2d_5 False
# zero_padding2d_6 False
# conv2d_6 False
# max_pooling2d_2 False
# zero_padding2d_7 False
# conv2d_7 False
# zero_padding2d_8 False
# conv2d_8 False
# zero_padding2d_9 False
# conv2d_9 False
# max_pooling2d_3 False
# zero_padding2d_10 False
# conv2d_10 False
# zero_padding2d_11 False
# conv2d_11 False
# zero_padding2d_12 False
# conv2d_12 False
# max_pooling2d_4 False
# conv2d_13 False
# dropout False
# conv2d_14 True
# dropout_1 True

# %%
model.fit(gen(train, train_person_to_images_map, input_shape, batch_size=16, normalization=NORMALIZATION), 
          validation_data=gen(val, val_person_to_images_map, input_shape, batch_size=16, normalization=NORMALIZATION), 
          epochs=25, verbose=1, use_multiprocessing=False, workers=1,
          callbacks=callbacks_list, steps_per_epoch=300, validation_steps=200)
# Out:
# Epoch 1/25
# 2021-08-09 12:39:32.708726: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-08-09 12:39:32.731290: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2300000000 Hz
# 2021-08-09 12:39:33.921364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-08-09 12:39:34.080340: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 300/300 [==============================] - 66s 211ms/step - loss: 0.7541 - acc: 0.5914 - val_loss: 0.6392 - val_acc: 0.6905
#
# Epoch 00001: val_acc improved from -inf to 0.69047, saving model to /root/KinshipRecognition/log/vgg_face_sigmoidtest_finetune.h5
# Epoch 2/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.6483 - acc: 0.6677 - val_loss: 0.6445 - val_acc: 0.6881
#
# Epoch 00002: val_acc did not improve from 0.69047
# Epoch 3/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.5739 - acc: 0.7253 - val_loss: 0.6467 - val_acc: 0.6817
#
# Epoch 00003: val_acc did not improve from 0.69047
# Epoch 4/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.5383 - acc: 0.7587 - val_loss: 0.6716 - val_acc: 0.6687
#
# Epoch 00004: val_acc did not improve from 0.69047
# Epoch 5/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.5415 - acc: 0.7529 - val_loss: 0.6889 - val_acc: 0.6478
#
# Epoch 00005: val_acc did not improve from 0.69047
# Epoch 6/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4983 - acc: 0.7736 - val_loss: 0.7005 - val_acc: 0.6469
#
# Epoch 00006: val_acc did not improve from 0.69047
# Epoch 7/25
# 300/300 [==============================] - 62s 209ms/step - loss: 0.4789 - acc: 0.7909 - val_loss: 0.7143 - val_acc: 0.6453
#
# Epoch 00007: val_acc did not improve from 0.69047
# Epoch 8/25
# 300/300 [==============================] - 62s 209ms/step - loss: 0.4636 - acc: 0.7986 - val_loss: 0.6966 - val_acc: 0.6686
#
# Epoch 00008: val_acc did not improve from 0.69047
# Epoch 9/25
# 300/300 [==============================] - 62s 209ms/step - loss: 0.4394 - acc: 0.8140 - val_loss: 0.7862 - val_acc: 0.6009
#
# Epoch 00009: val_acc did not improve from 0.69047
# Epoch 10/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4408 - acc: 0.8102 - val_loss: 0.7319 - val_acc: 0.6498
#
# Epoch 00010: val_acc did not improve from 0.69047
# Epoch 11/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4138 - acc: 0.8244 - val_loss: 0.7484 - val_acc: 0.6233
#
# Epoch 00011: val_acc did not improve from 0.69047
# Epoch 12/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4237 - acc: 0.8186 - val_loss: 0.7627 - val_acc: 0.6448
#
# Epoch 00012: val_acc did not improve from 0.69047
# Epoch 13/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4111 - acc: 0.8219 - val_loss: 0.8016 - val_acc: 0.6030
#
# Epoch 00013: val_acc did not improve from 0.69047
# Epoch 14/25
# 300/300 [==============================] - 63s 209ms/step - loss: 0.4019 - acc: 0.8296 - val_loss: 0.7907 - val_acc: 0.6316
#
# Epoch 00014: val_acc did not improve from 0.69047
# Epoch 15/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.4048 - acc: 0.8301 - val_loss: 0.7950 - val_acc: 0.6137
#
# Epoch 00015: val_acc did not improve from 0.69047
# Epoch 16/25
# 300/300 [==============================] - 62s 208ms/step - loss: 0.3807 - acc: 0.8448 - val_loss: 0.8039 - val_acc: 0.6094
#
# Epoch 00016: val_acc did not improve from 0.69047
# Epoch 17/25
# 192/300 [==================>...........] - ETA: 13s - loss: 0.3749 - acc: 0.8463
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17868/103130182.py in <module>
# ----> 1 model.fit(gen(train, train_person_to_images_map, input_shape, batch_size=16, normalization=NORMALIZATION),
#       2           validation_data=gen(val, val_person_to_images_map, input_shape, batch_size=16, normalization=NORMALIZATION),
#       3           epochs=25, verbose=1, use_multiprocessing=False, workers=1,
#       4           callbacks=callbacks_list, steps_per_epoch=300, validation_steps=200)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Modify paths as per your need
test_path = f"{BASE_PATH}/data/test/"

model = baseline_model(BASE_MODEL, fine_tune=True)
model.load_weights(f"{BASE_PATH}/log/vgg_face_sigmoidtest_finetune.h5")

submission = pd.read_csv(f'{BASE_PATH}/data/test_ds.csv')
predictions = []

for i in range(0, len(submission.p1.values), 32):
    X1 = submission.p1.values[i:i+32]
    X1 = np.array([read_img(test_path + x, input_shape, normalization=NORMALIZATION) for x in X1])

    X2 = submission.p2.values[i:i+32]
    X2 = np.array([read_img(test_path + x, input_shape, normalization=NORMALIZATION) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    # pred = model([X1, X2], training=True).numpy().ravel().tolist()
    predictions += pred

# %%
print(np.sum(np.asarray(predictions) < .5))
print(len(predictions))
for line in predictions:
    print(line)

# %% [markdown]
# The final predictions will need to be rounded: EG 0.01 rounded to 0 and 0.78 rounded to 1. The simple .round() function is sufficient as below.

# %%
# predictions = np.asarray(predictions)
# predictions[predictions <= .60] = 0
d = {'index': np.arange(0, 3000, 1), 'label':predictions}
submissionfile = pd.DataFrame(data=d)
submissionfile = submissionfile.round()

# %%
submissionfile.astype("int64").to_csv(f"{BASE_PATH}/log/results/aug_vggface_full_tunetop2_32-128-32_F06_mirrorface.csv", index=False)

# %%
XX = model.input 
YY = model.layers[-2].output
new_model = Model(XX, YY)
out = new_model.predict([X1, X2, X1_mirror, X2_mirror])
print(out)
print(model.layers[-1].weights)

# %% [markdown]
# At this point, download the CSV and submit it on Kaggle to score your predictions.

# %% [markdown]
# ## Detect Face and Rotate Image

# %%
# !pip install deepface

# %%
# import cv2
# from deepface import DeepFace
# import matplotlib.pyplot as plt
# import matplotlib.image as mimg
# import os

# %%
# in_path = "./drive/MyDrive/KinshipRecognitionStarter/test/"
# out_path = "./drive/MyDrive/KinshipRecognitionStarter/new_test/"
# image_list = os.listdir(in_path)
# for x in image_list:
#   img = DeepFace.detectFace(in_path + x, align=True, detector_backend='mtcnn', enforce_detection=False)
#   mimg.imsave(out_path + x, img)

# %%
# import shutil
# in_path = "./drive/MyDrive/KinshipRecognitionStarter/train/train-faces"
# for x in os.listdir(in_path):
#   try:
#     for y in os.listdir(in_path + "/" + x):
#       print(in_path + "/" + x + "/" + y)
#       try:
#         for z in os.listdir(in_path + "/" + x + "/" + y):
#           filepath = in_path + "/" + x + "/" + y + "/" + z
#           img = DeepFace.detectFace(filepath, align=True, detector_backend='mtcnn', enforce_detection=False)
#           mimg.imsave(filepath, img)
#       except NotADirectoryError:
#           continue
#   except NotADirectoryError:
#       continue
